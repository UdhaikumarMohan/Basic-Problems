# %% [markdown]
# Axes: Tricks,Range,legends

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales.csv',parse_dates=['Date'])
df['Month'] = df['Date'].dt.month
sales = df.groupby(["Month",'Product'])['Amount'].sum().unstack
sales()
# Out:
# Product        a        b        c
# Month
# 1         7260.0   9258.0   1740.0
# 2         6534.0      NaN   5000.0
# 3         7260.0      NaN   2117.0
# 4        11616.0  13221.0   5440.0
# 5         7119.0      NaN   2990.0
# 6        11071.0      NaN   7176.0
# 7         4200.0  15973.0   2901.0
# 8        10342.0      NaN   6662.0
# 9            NaN      NaN    660.0
# 10        2100.0  10711.0  14520.0
# 11        7260.0      NaN   3710.0
# 12       11616.0  14800.0      NaN

# %%
fig, ax = plt.subplots()
sales().plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Main Properties of Axes:
#
# Limit value where the axis starts and ends
#
# Tricks position of indicator line on the axis
#
# Tricks labels : text shown at tricks.

# %%
styles ={'a':':s', 'b':'--v', 'c':'-.o'}

with plt.style.context('seaborn-dark'):
    
    fig, ax=plt.subplots(figsize=(6,3))
    
    for column in styles:
        
        sales[column].dropna().plot(ax=ax,style=styles)
# Out:
# <div id='4b865e82-2e6e-47b2-b9fd-cedb1754fe40'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1de498a8524c> in <module>()
#       7     for column in styles:
#       8
# ----> 9         sales[column].dropna().plot(ax=ax,style=styles)
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
for column in styles:
    
    sales[columns].dropna().plot(ax=ax,style=styles[column],grid=True,ylim=(0,2000),legend=True,label='product'+column)

ax.set_title('Monthly sales')
ax.set_ylabel('sales(EUR)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6cb7b5832779> in <module>()
#       1 for column in styles:
#       2
# ----> 3     sales[columns].dropna().plot(ax=ax,style=styles[column],grid=True,ylim=(0,2000),legend=True,label='product'+column)
#       4
#       5 ax.set_title('Monthly sales')
#
# NameError: name 'columns' is not defined

# %%
ax.set_xtricks(range(1,13))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0f65e3824fc7> in <module>()
# ----> 1 ax.set_xtricks(range(1,13))
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xtricks'

# %%
import calander

ax.set_xtricklabels([calander,month_name[x] for x in sales.index],rotation=30, ha='right')
# Out:
#   File "<ipython-input-10-1e918942fa47>", line 3
#     ax.set_xtricklabels([calander,month_name[x] for x in sales.index],rotation=30, ha='right')
#                                                   ^
# SyntaxError: invalid syntax
