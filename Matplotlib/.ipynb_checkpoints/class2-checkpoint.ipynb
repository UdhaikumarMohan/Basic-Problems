# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')

# %%
df = pd.read_csv('sales.csv', parse_dates=['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
# Date       50 non-null datetime64[ns]
# Amount     50 non-null int64
# Product    50 non-null object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df.head()
# Out:
#         Date  Amount Product
# 0 2017-01-20    5411       b
# 1 2017-02-22    5000       c
# 2 2017-03-01    7260       a
# 3 2017-03-14    2117       c
# 4 2017-04-15    7516       b

# %%
df['Month']=df['Date'].dt.month
df.head()
# Out:
#         Date  Amount Product  Month
# 0 2017-01-20    5411       b      1
# 1 2017-02-22    5000       c      2
# 2 2017-03-01    7260       a      3
# 3 2017-03-14    2117       c      3
# 4 2017-04-15    7516       b      4

# %%
g = df.groupby(['Month','Product'])['Amount'].sum()
g
# Out:
# Month  Product
# 1      a           7260
#        b           9258
#        c           1740
# 2      a           6534
#        c           5000
# 3      a           7260
#        c           2117
# 4      a          11616
#        b          13221
#        c           5440
# 5      a           7119
#        c           2990
# 6      a          11071
#        c           7176
# 7      a           4200
#        b          15973
#        c           2901
# 8      a          10342
#        c           6662
# 9      c            660
# 10     a           2100
#        b          10711
#        c          14520
# 11     a           7260
#        c           3710
# 12     a          11616
#        b          14800
# Name: Amount, dtype: int64

# %%
g = g.unstack()
g
# Out:
# Product        a        b        c
# Month
# 1         7260.0   9258.0   1740.0
# 2         6534.0      NaN   5000.0
# 3         7260.0      NaN   2117.0
# 4        11616.0  13221.0   5440.0
# 5         7119.0      NaN   2990.0
# 6        11071.0      NaN   7176.0
# 7         4200.0  15973.0   2901.0
# 8        10342.0      NaN   6662.0
# 9            NaN      NaN    660.0
# 10        2100.0  10711.0  14520.0
# 11        7260.0      NaN   3710.0
# 12       11616.0  14800.0      NaN

# %%
revenue = g.fillna(0).cumsum()
revenue
# Out:
# Product        a        b        c
# Month
# 1         7260.0   9258.0   1740.0
# 2        13794.0   9258.0   6740.0
# 3        21054.0   9258.0   8857.0
# 4        32670.0  22479.0  14297.0
# 5        39789.0  22479.0  17287.0
# 6        50860.0  22479.0  24463.0
# 7        55060.0  38452.0  27364.0
# 8        65402.0  38452.0  34026.0
# 9        65402.0  38452.0  34686.0
# 10       67502.0  49163.0  49206.0
# 11       74762.0  49163.0  52916.0
# 12       86378.0  63963.0  52916.0

# %%
ax = revenue.plot.area(title='Revenue Analysis')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots()
revenue.plot.area(title='Revenue Analysis',ax=ax,stacked=False,grid=True)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
total_revenue = df.groupby('Month')["Amount"].sum().cumsum()
total_revenue
# Out:
# Month
# 1      18258
# 2      29792
# 3      39169
# 4      69446
# 5      79555
# 6      97802
# 7     120876
# 8     137880
# 9     138540
# 10    165871
# 11    176841
# 12    203257
# Name: Amount, dtype: int64

# %%
fig, ax=plt.subplots()
total_revenue.plot(ax=ax,style='r--',legend=True,label='All')
revenue.plot.area(title='Revenue Analysis',ax=ax,staked=False,grid=True)

fig.tight_layout()
# Out:
# <div id='d130166d-1b4a-4151-a384-6095ebb039eb'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-158ae06ea106> in <module>()
#       1 fig, ax=plt.subplots()
#       2 total_revenue.plot(ax=ax,style='r--',legend=True,label='All')
# ----> 3 revenue.plot.area(title='Revenue Analysis',ax=ax,staked=False,grid=True)
#       4
#       5 fig.tight_layout()
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in area(self, x, y, **kwds)
#    3328         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    3329         """
# -> 3330         return self(kind='area', x=x, y=y, **kwds)
#    3331
#    3332     def pie(self, y=None, **kwds):
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in _make_plot(self)
#     983                              stacking_id=stacking_id,
#     984                              is_errorbar=is_errorbar,
# --> 985                              **kwds)
#     986             self._add_legend_handle(newlines[0], label, index=i)
#     987
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1117         if cls.mpl_ge_1_5_0():
#    1118             line_kwds.pop('label')
# -> 1119         lines = MPLPlot._plot(ax, x, y_values, style=style, **line_kwds)
#    1120
#    1121         # get data from the line to get coordinates for fill_between
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     613             else:
#     614                 args = (x, y)
# --> 615             return ax.plot(*args, **kwds)
#     616
#     617     def _get_index_name(self):
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     394                                   "with non-matching shapes is deprecated.")
#     395         for j in xrange(max(ncx, ncy)):
# --> 396             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     397             ret.append(seg)
#     398         return ret
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _makeline(self, x, y, kw, kwargs)
#     298         default_dict = self._getdefaults(None, kw)
#     299         self._setdefaults(default_dict, kw)
# --> 300         seg = mlines.Line2D(x, y, **kw)
#     301         return seg
#     302
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     419         # update kwargs before updating data to give the caller a
#     420         # chance to init axes (and hence unit support)
# --> 421         self.update(kwargs)
#     422         self.pickradius = pickradius
#     423         self.ind_offset = 0
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\artist.pyc in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\artist.pyc in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property staked
